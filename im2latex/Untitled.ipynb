# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"></ul></div>

# %%
train_formulas = open("./data/train.formulas.norm.txt")
train_matching = open("./data/train.matching.txt")

lengths=sorted([len(line.split()) for line in train_formulas.readlines()], reverse=True)

train_formulas.close()
train_matching.close()

# %%
lengths
# Out:
# [150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  149,
#  149,
#  149,
#  149,
#  149,
#  149,
#  149,
#  149,
#  149,
#  148,
#  148,
#  148,
#  148,
#  148,
#  148,
#  148,
#  148,
#  148,
#  148,
#  148,
#  148,
#  148,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  146,
#  146,
#  146,
#  146,
#  146,
#  146,
#  146,
#  146,
#  146,
#  146,
#  146,
#  146,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  143,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  141,
#  141,
#  141,
#  141,
#  141,
#  141,
#  141,
#  141,
#  141,
#  141,
# ...
